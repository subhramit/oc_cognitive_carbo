# %%
import os as os
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\subhr'

# %%
# %cd C:\Users\subhr\OneDrive\Desktop
# Out:
# C:\Users\subhr\OneDrive\Desktop

# %%
df = pd.read_excel('GSE15622_labeled.xlsx')

# %%
df.head()
# Out:
#            ID_REF  GSM391100  GSM391101  GSM391102  GSM391089  GSM391090  \
# 0  AFFX-BioB-3_at   6.789838   6.847418   6.551068   6.490364   6.507760
# 1  AFFX-BioB-5_at   6.822405   6.857746   6.687019   6.569997   6.491633
# 2  AFFX-BioB-M_at   7.074762   7.051129   6.940744   6.791347   6.774486
# 3  AFFX-BioC-3_at   7.430151   8.011986   7.806440   7.715539   7.550530
# 4  AFFX-BioC-5_at   7.458039   7.934932   7.753574   7.666375   7.497900
#
#    GSM391083  GSM391071  GSM391072  GSM391062  ...  GSM391078  GSM391079  \
# 0   6.612067   8.031492   7.107762   7.142613  ...   7.073314   6.737643
# 1   6.556502   8.053802   7.086599   7.203858  ...   6.940144   6.630088
# 2   6.845298   8.989949   7.337085   7.657960  ...   7.417163   7.069601
# 3   7.722867   9.835766   8.384944   8.427223  ...   7.823371   7.988510
# 4   7.739847   9.993778   8.285465   8.271483  ...   7.819376   7.905167
#
#    GSM391081  GSM391082  GSM391084  GSM391085  GSM391087  GSM391088 GSM391094  \
# ...

# %%
df = df.transpose()

# %%
df.to_csv('workable_carbo.csv', index=True, header = False)

# %%
df = pd.read_csv('workable_carbo.csv',index_col=0)

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.svm import SVC
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df['AFFX-CreX-5_at']['GSM391073'] = 11.76
# Out:
# C:\Users\subhr\AppData\Local\Temp/ipykernel_14568/1466942854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AFFX-CreX-5_at']['GSM391073'] = 11.76

# %%
X = df.drop('Class', axis = 'columns')

# %%
X
# Out:
#            AFFX-BioB-3_at  AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioC-3_at  \
# ID_REF
# GSM391100        6.789838        6.822405        7.074762        7.430151
# GSM391101        6.847418        6.857746        7.051129        8.011986
# GSM391102        6.551068        6.687019        6.940744        7.806440
# GSM391089        6.490364        6.569997        6.791347        7.715539
# GSM391090        6.507760        6.491633        6.774486        7.550530
# GSM391083        6.612067        6.556502        6.845298        7.722867
# GSM391071        8.031492        8.053802        8.989949        9.835766
# GSM391072        7.107762        7.086599        7.337085        8.384944
# GSM391062        7.142613        7.203858        7.657960        8.427223
# GSM391064        6.913419        6.772213        7.283274        8.148960
# GSM391065        6.793140        6.839875        7.099291        8.037688
# GSM391058        7.888791        7.835721        8.376686        9.632911
# ...

# %%
y = df['Class']

# %%
y
# Out:
# ID_REF
# GSM391100    0.0
# GSM391101    0.0
# GSM391102    0.0
# GSM391089    0.0
# GSM391090    0.0
# GSM391083    0.0
# GSM391071    0.0
# GSM391072    0.0
# GSM391062    0.0
# GSM391064    0.0
# GSM391065    0.0
# GSM391058    1.0
# GSM391059    1.0
# GSM391060    1.0
# GSM391061    1.0
# GSM391068    1.0
# GSM391069    1.0
# GSM391073    1.0
# GSM391074    1.0
# GSM391078    1.0
# GSM391079    1.0
# GSM391081    1.0
# GSM391082    1.0
# GSM391084    1.0
# GSM391085    1.0
# GSM391087    1.0
# GSM391088    1.0
# GSM391094    1.0
# GSM391095    1.0
# Name: Class, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
len(X_train)
# Out:
# 23

# %%
len(X_test)
# Out:
# 6

# %%
model = SVC()

# %%
kay = model.fit(X_train,y_train)

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334
